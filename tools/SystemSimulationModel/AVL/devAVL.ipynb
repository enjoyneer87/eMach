# %%
import sys
sys.path.append(r'C:\Program Files (x86)\AVL\R2024.1\user_python')

# %%
import sdt

# %%
import sdt.project
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import sdt.project
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:655, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap>:618, in _load_backward_compatible(spec)
#
# File _import_sdt_impl:21, in _SdtImporterBase.load_module(self, fullname)
#      19     return sys.modules[fullname]
#      20 assert fullname == 'sdt' or fullname.startswith('sdt.')
# ---> 21 is_pkg = self._check_import(fullname)
#      22 mod = self._make_module(fullname, is_pkg)
#      23 sys.modules[fullname] = mod
#
# File _import_sdt_impl:31, in _SdtImporterBase._check_import(self, fullname)
#      29 def _check_import(self, fullname):
#      30     __skip_interactive_traceback__ = True
# ---> 31     valid, is_pkg = _sandbox_exec.host_call('__sdt_scripting__', 'check_import', (fullname,))
#      32     if not valid:
#      33         raise ImportError("No module named %s" % fullname)
#
# File _sandbox_exec:344, in host_call(obj_key, method, args, kwds)
#
# File _sandbox_exec:420, in _safe_send(obj)
#
# RuntimeError: SDT scripting in foreground sandbox mode can only be used from the thread that imported it

# %%
from __future__ import print_function
import sdt.project
import sdt.excite

project = sdt.project.create_project()
model = project.create_model('excite_eaxle')

## gear assembly
gearBox = model.insert(model.root, 'gearbox')

# gear element
gg = model.insert(gearBox, 'gearbox Globals')

## Motor Rotor
# generic shaft -> rotor

# shaft bearing seat 


## Planetary Gearset 
pgs = model.insert(model.root, 'Planetary Gearset')


## Ring Housing

## Reducer 

# Generic Shaft -> Reducer Shaft (Input Shaft)

## Wheel
# 
# Reducer Shaft (Output Shaft) -> Wheel Hub



## chassis

# chassis node


## Joint Definitions
