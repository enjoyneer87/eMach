# %% [markdown]
# insert table of contents here
# # Introduction

# %%
import sys
import os
import ctypes
import scipy.io as sio

# mainJplotReader.py 파일이 있는 경로를 추가
module_path ='C:\Program Files\JMAG-Designer23.1\Tools\JPlotReader\samples\Python'
if module_path not in sys.path:
    sys.path.append(module_path)

# 모듈 가져오기
import mainJplotReader as jpr
from JplotReader import JplotReader

# %%
import subprocess
import os

# 기본 jplot 경로 패턴
SCL_jplot_path = r"E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case{}\Designer.jplot"
forPath = SCL_jplot_path

# Case1부터 Case30까지 처리
for case_number in range(21, 31):  # 1부터 30까지 실행
    # 각 case 번호에 따라 경로 생성
    current_jplot_path = forPath.format(case_number)

    # 파일 경로 및 변수 설정
    base_xml_path = r"D:\KangDH\Emlab_emach\mlxperPJT\JEET\From38100\MPtools\MS_conductorBase.xml"
    result_jplot_path = current_jplot_path  # 동적으로 변경된 jplot 경로
    mesh_path = r"D:\KangDH\Emlab_emach\mlxperPJT\From38100\MPtools\mesh.nas"

    csvPath=r"D:\KangDH\Emlab_emach\mlxperPJT\JEET\From38100\MPtools\MSConductorModel_case{}.csv"
    # output 파일 경로를 동적으로 생성 (case 번호에 따라)
    output_csv_path = csvPath.format(case_number)

    # 실행할 명령어 구성
    command = [
        r"C:\Program Files\JMAG-Designer23.1\GeneralInterfaceDriver.exe",
        "-in", base_xml_path,
        "-input", result_jplot_path,  # 동적으로 설정된 경로 사용
        "-output", output_csv_path,  # 동적으로 설정된 경로 사용
        "-start_step", "1",
        "-end_step", "121"
    ]

    # 명령 실행

    result = subprocess.run(command, shell=True)
# 경로 확인 코드
    if not os.path.exists(result_jplot_path):
        print(f"Error: {result_jplot_path} does not exist.")
    if not os.path.exists(base_xml_path):
        print(f"Error: {base_xml_path} does not exist.")
    # if not os.path.exists(mesh_path):
        # print(f"Error: {mesh_path} does not exist.")
    if result.returncode == 0:
        print(f'Command executed successfully for case {case_number}')
    else:
        print(f'Command failed for case {case_number}')
# Out:
# Command executed successfully for case 21
# Command executed successfully for case 22
# Command executed successfully for case 23
# Command executed successfully for case 24
# Command executed successfully for case 25
# Command executed successfully for case 26
# Command executed successfully for case 27

# %%
print("Executing command: " + ' '.join(command))
# Out:
# Executing command: C:\Program Files\JMAG-Designer23.1\GeneralInterfaceDriver.exe -in D:\KangDH\Emlab_emach\mlxperPJT\JEET\From38100\MPtools\MS_conductor.xml -input E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot -output D:\KangDH\Emlab_emach\mlxperPJT\JEET\From38100\MPtools\MSConductorModel_case1.csv -start_step 1 -end_step 121

# %%
result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
print(result.stdout.decode())  # 표준 출력 확인
print(result.stderr.decode())  # 오류 출력 확인
# Out:
# Encoding = utf-8
# Checkout: JMAG_MPFE_INTERFACE
# Encoding = utf-8
# Encoding = utf-8
# Rewriting Arguments : -input is rewirtten : [1] E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case1/Designer.jplot
# Rewriting Arguments : -start_step is rewirtten : [1] 1
# Rewriting Arguments : -end_step is rewirtten : [1] 121
# UTF-8 file name = D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools/MS_Conductor_C28.csv
# S-JIS file name = D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools/MS_Conductor_C28.csv
# UTF-8 file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case28/Designer.jplot
# S-JIS file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case28/Designer.jplot
# UTF-8 file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case1/Designer.jplot
# S-JIS file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case1/Designer.jplot
# filename = E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot
# filename = E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot
# mesh_model_file = E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case28\Designer.jplot
# WARNING
# code : 46022
# model extension parameters are not found.
# Using binary reader
# JCoupled parameter file path : D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools\MS_Conductor_C28_jcoupled.xml
# JCoupled  isOneWay = 1 in -mode=control
# JCoupled  originalFilePaths.size() = 2
# JCoupled  originalFilePaths[0] : d:\KangDH\Emlab_emach\tools\jmag\jplotReader\input.nas
#
# Microsoft Windows [Version 10.0.19045.2728]
# argv[0]: C:\Program Files\JMAG-Designer23.1\JCoupled.exe
# argv[1]: -mode=control
# argv[2]: D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools\MS_Conductor_C28_jcoupled.xml
# argv[3]: -mpfet
# found env WorkDir : d:\KangDH\Emlab_emach\tools\jmag\jplotReader
# JCoupled parameter file path : D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools\MS_Conductor_C28_jcoupled.xml
# JCoupled  isOneWay = 1 in -mode=control
# JCoupled  originalFilePaths.size() = 2
# JCoupled  originalFilePaths[0] : d:\KangDH\Emlab_emach\tools\jmag\jplotReader\input.nas
# InsDir  = C:\Program Files\JMAG-Designer23.1
# WorkDir = d:\KangDH\Emlab_emach\tools\jmag\jplotReader
# cash size per page : 400 (kb)
# set absolute working root path from env WorkDir : d:\KangDH\Emlab_emach\tools\jmag\jplotReader
# D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools\MS_Conductor_C28_jcoupled.xml
# -mode=control
# -mpfet=
#
# **** read control file ****
#   calling TLicenseControl::CheckInAll().
#   called TLicenseControl::CheckInAll().
# use simpleCheckoutLicense().
# start to setup the general interface analysis runner
# finish to setup the general interface analysis runner
# start to setup the reference file runner
# reference file path = E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot
#   JmagJcfFileHandleList  added handle of "E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot" : list size = 1
#   strPeriodicBoundary = CyclicBoundary, numPeriodicBoundary = 1
# finish to setup the reference file runner
# **** write JCoupled parameter echo back file ****
# ===> d:\KangDH\Emlab_emach\tools\jmag\jplotReader
# <=== d:\KangDH\Emlab_emach\tools\jmag\jplotReader
# start to prepare the reference file runner
# jmag source model dimension = dim2
# finish to prepare the reference file runner
# ===> d:\KangDH\Emlab_emach\tools\jmag\jplotReader
# <=== d:\KangDH\Emlab_emach\tools\jmag\jplotReader
# Features = JMAG_MPFE_INTERFACE
# Features = JMAG_MPFE_INTERFACE
#   calling Checkout().
#   called Checkout().
# Checkout: JMAG_MPFE_INTERFACE, count = 1
# set by Mapper default limit (Mapper::SetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# start to pull references of the general interface analysis runner
#   found output mesh model type : from_jmag_result_file
#   found output mesh length unit = mm
#   found output mesh dimension = 2
#   reference coordinate id = 1, z axis vector(0,0,1)
#   number of reference coordinate systems = 1
#   extend_2d_to_3d = 0 in conditionIndex = 0
#   nastran bulk model is 2 dimensional. 4
# mpfet progress rate : 0[%]
#   JplotKeyResultType version : 22.1.0b
#   extend 2d to 3d, flag to use Number Of ZValues = 0 in conditionIndex = 0
#   reference_coordinate_id= 1
#   reference_coordinate_origin= (0,0,0)
#   reference_coordinate_point_on_x= (0.001,0,0)
#   reference_coordinate_point_on_xy= (0,0.001,0)
# mpfet set size of map for all components = 1
# mpfet set size of fft for all components = 0
# mpfet set size of write file for all components = 1
# start distributed value conversion.
#   component = vector_potential
# jplot file is used for geometry information.
# filter type = (empty)
# reading source result...
#   read distributed value from start_step= 1 to end_step=121
# read jplot file : E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot
#   component = vector_potential, key-id = 11005, is-distributed-value = 1
#   number of steps = 121
# change cash size per page : 400 (kb) -> 3305 (kb)
#   number of values = 14231 in step 0, step id = 1  [1/121]
# change cash size per page : 3305.78 (kb) -> 3305.78 (kb)
#   number of values = 14231 in step 1, step id = 2  [2/121]
#   number of values = 14231 in step 2, step id = 3  [3/121]
#   number of values = 14231 in step 3, step id = 4  [4/121]
#   number of values = 14231 in step 4, step id = 5  [5/121]
#   number of values = 14231 in step 5, step id = 6  [6/121]
#   number of values = 14231 in step 6, step id = 7  [7/121]
#   number of values = 14231 in step 7, step id = 8  [8/121]
#   number of values = 14231 in step 8, step id = 9  [9/121]
#   number of values = 14231 in step 9, step id = 10  [10/121]
#   number of values = 14231 in step 10, step id = 11  [11/121]
#   number of values = 14231 in step 11, step id = 12  [12/121]
#   number of values = 14231 in step 12, step id = 13  [13/121]
#   number of values = 14231 in step 13, step id = 14  [14/121]
#   number of values = 14231 in step 14, step id = 15  [15/121]
#   number of values = 14231 in step 15, step id = 16  [16/121]
#   number of values = 14231 in step 16, step id = 17  [17/121]
#   number of values = 14231 in step 17, step id = 18  [18/121]
#   number of values = 14231 in step 18, step id = 19  [19/121]
#   number of values = 14231 in step 19, step id = 20  [20/121]
#   number of values = 14231 in step 20, step id = 21  [21/121]
#   number of values = 14231 in step 21, step id = 22  [22/121]
#   number of values = 14231 in step 22, step id = 23  [23/121]
#   number of values = 14231 in step 23, step id = 24  [24/121]
#   number of values = 14231 in step 24, step id = 25  [25/121]
#   number of values = 14231 in step 25, step id = 26  [26/121]
#   number of values = 14231 in step 26, step id = 27  [27/121]
#   number of values = 14231 in step 27, step id = 28  [28/121]
#   number of values = 14231 in step 28, step id = 29  [29/121]
#   number of values = 14231 in step 29, step id = 30  [30/121]
#   number of values = 14231 in step 30, step id = 31  [31/121]
#   number of values = 14231 in step 31, step id = 32  [32/121]
#   number of values = 14231 in step 32, step id = 33  [33/121]
#   number of values = 14231 in step 33, step id = 34  [34/121]
#   number of values = 14231 in step 34, step id = 35  [35/121]
#   number of values = 14231 in step 35, step id = 36  [36/121]
#   number of values = 14231 in step 36, step id = 37  [37/121]
#   number of values = 14231 in step 37, step id = 38  [38/121]
#   number of values = 14231 in step 38, step id = 39  [39/121]
#   number of values = 14231 in step 39, step id = 40  [40/121]
#   number of values = 14231 in step 40, step id = 41  [41/121]
#   number of values = 14231 in step 41, step id = 42  [42/121]
#   number of values = 14231 in step 42, step id = 43  [43/121]
#   number of values = 14231 in step 43, step id = 44  [44/121]
#   number of values = 14231 in step 44, step id = 45  [45/121]
#   number of values = 14231 in step 45, step id = 46  [46/121]
#   number of values = 14231 in step 46, step id = 47  [47/121]
#   number of values = 14231 in step 47, step id = 48  [48/121]
#   number of values = 14231 in step 48, step id = 49  [49/121]
#   number of values = 14231 in step 49, step id = 50  [50/121]
#   number of values = 14231 in step 50, step id = 51  [51/121]
#   number of values = 14231 in step 51, step id = 52  [52/121]
#   number of values = 14231 in step 52, step id = 53  [53/121]
#   number of values = 14231 in step 53, step id = 54  [54/121]
#   number of values = 14231 in step 54, step id = 55  [55/121]
#   number of values = 14231 in step 55, step id = 56  [56/121]
#   number of values = 14231 in step 56, step id = 57  [57/121]
#   number of values = 14231 in step 57, step id = 58  [58/121]
#   number of values = 14231 in step 58, step id = 59  [59/121]
#   number of values = 14231 in step 59, step id = 60  [60/121]
#   number of values = 14231 in step 60, step id = 61  [61/121]
#   number of values = 14231 in step 61, step id = 62  [62/121]
#   number of values = 14231 in step 62, step id = 63  [63/121]
#   number of values = 14231 in step 63, step id = 64  [64/121]
#   number of values = 14231 in step 64, step id = 65  [65/121]
#   number of values = 14231 in step 65, step id = 66  [66/121]
#   number of values = 14231 in step 66, step id = 67  [67/121]
#   number of values = 14231 in step 67, step id = 68  [68/121]
#   number of values = 14231 in step 68, step id = 69  [69/121]
#   number of values = 14231 in step 69, step id = 70  [70/121]
#   number of values = 14231 in step 70, step id = 71  [71/121]
#   number of values = 14231 in step 71, step id = 72  [72/121]
#   number of values = 14231 in step 72, step id = 73  [73/121]
#   number of values = 14231 in step 73, step id = 74  [74/121]
#   number of values = 14231 in step 74, step id = 75  [75/121]
#   number of values = 14231 in step 75, step id = 76  [76/121]
#   number of values = 14231 in step 76, step id = 77  [77/121]
#   number of values = 14231 in step 77, step id = 78  [78/121]
#   number of values = 14231 in step 78, step id = 79  [79/121]
#   number of values = 14231 in step 79, step id = 80  [80/121]
#   number of values = 14231 in step 80, step id = 81  [81/121]
#   number of values = 14231 in step 81, step id = 82  [82/121]
#   number of values = 14231 in step 82, step id = 83  [83/121]
#   number of values = 14231 in step 83, step id = 84  [84/121]
#   number of values = 14231 in step 84, step id = 85  [85/121]
#   number of values = 14231 in step 85, step id = 86  [86/121]
#   number of values = 14231 in step 86, step id = 87  [87/121]
#   number of values = 14231 in step 87, step id = 88  [88/121]
#   number of values = 14231 in step 88, step id = 89  [89/121]
#   number of values = 14231 in step 89, step id = 90  [90/121]
#   number of values = 14231 in step 90, step id = 91  [91/121]
#   number of values = 14231 in step 91, step id = 92  [92/121]
#   number of values = 14231 in step 92, step id = 93  [93/121]
#   number of values = 14231 in step 93, step id = 94  [94/121]
#   number of values = 14231 in step 94, step id = 95  [95/121]
#   number of values = 14231 in step 95, step id = 96  [96/121]
#   number of values = 14231 in step 96, step id = 97  [97/121]
#   number of values = 14231 in step 97, step id = 98  [98/121]
#   number of values = 14231 in step 98, step id = 99  [99/121]
#   number of values = 14231 in step 99, step id = 100  [100/121]
#   number of values = 14231 in step 100, step id = 101  [101/121]
#   number of values = 14231 in step 101, step id = 102  [102/121]
#   number of values = 14231 in step 102, step id = 103  [103/121]
#   number of values = 14231 in step 103, step id = 104  [104/121]
#   number of values = 14231 in step 104, step id = 105  [105/121]
#   number of values = 14231 in step 105, step id = 106  [106/121]
#   number of values = 14231 in step 106, step id = 107  [107/121]
#   number of values = 14231 in step 107, step id = 108  [108/121]
#   number of values = 14231 in step 108, step id = 109  [109/121]
#   number of values = 14231 in step 109, step id = 110  [110/121]
#   number of values = 14231 in step 110, step id = 111  [111/121]
#   number of values = 14231 in step 111, step id = 112  [112/121]
#   number of values = 14231 in step 112, step id = 113  [113/121]
#   number of values = 14231 in step 113, step id = 114  [114/121]
#   number of values = 14231 in step 114, step id = 115  [115/121]
#   number of values = 14231 in step 115, step id = 116  [116/121]
#   number of values = 14231 in step 116, step id = 117  [117/121]
#   number of values = 14231 in step 117, step id = 118  [118/121]
#   number of values = 14231 in step 118, step id = 119  [119/121]
#   number of values = 14231 in step 119, step id = 120  [120/121]
#   number of values = 14231 in step 120, step id = 121  [121/121]
# repeating map mode OFF
# reading source geometry...
#   found the previous jcf mesh geometry of 'E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot'
#   number of parts = 8 limited by source_target_part
#   strPeriodicBoundary = CyclicBoundary, numPeriodicBoundary = 1
# Using binary reader
# read jcf file : E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot
#   CutPlaneProjection adopted
# Using binary reader
#   read jcf mesh model.
#   read jcf mesh model.  number of nodes = 14231, elements = 27274
#   nodal periodic boundary index = 0 ignored !
# Using binary reader
#   number of nodes = 14231, elements = 27274, A
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# Using num_threads(in setNextElemMt) = 8
# numelems = 27274
# Using num_threads(in setNextElemMt1) = 8
# numelems = 27274
# Using num_threads(in setModelSizeMt) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# copying element adcacency information...,  numelems = 27274
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# Using num_threads(in setModelSizeMt) = 8
# read jplot file : E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot
#   component = step_disp_group, key-id = 110001, is-distributed-value = 0
#   number of steps = 121
# change cash size per page : 3305 (kb) -> 400 (kb)
#   number of values = 1 in step 0, step id = 1  [1/121]
#   number of values = 1 in step 1, step id = 2  [2/121]
#   number of values = 1 in step 2, step id = 3  [3/121]
#   number of values = 1 in step 3, step id = 4  [4/121]
#   number of values = 1 in step 4, step id = 5  [5/121]
#   number of values = 1 in step 5, step id = 6  [6/121]
#   number of values = 1 in step 6, step id = 7  [7/121]
#   number of values = 1 in step 7, step id = 8  [8/121]
#   number of values = 1 in step 8, step id = 9  [9/121]
#   number of values = 1 in step 9, step id = 10  [10/121]
#   number of values = 1 in step 10, step id = 11  [11/121]
#   number of values = 1 in step 11, step id = 12  [12/121]
#   number of values = 1 in step 12, step id = 13  [13/121]
#   number of values = 1 in step 13, step id = 14  [14/121]
#   number of values = 1 in step 14, step id = 15  [15/121]
#   number of values = 1 in step 15, step id = 16  [16/121]
#   number of values = 1 in step 16, step id = 17  [17/121]
#   number of values = 1 in step 17, step id = 18  [18/121]
#   number of values = 1 in step 18, step id = 19  [19/121]
#   number of values = 1 in step 19, step id = 20  [20/121]
#   number of values = 1 in step 20, step id = 21  [21/121]
#   number of values = 1 in step 21, step id = 22  [22/121]
#   number of values = 1 in step 22, step id = 23  [23/121]
#   number of values = 1 in step 23, step id = 24  [24/121]
#   number of values = 1 in step 24, step id = 25  [25/121]
#   number of values = 1 in step 25, step id = 26  [26/121]
#   number of values = 1 in step 26, step id = 27  [27/121]
#   number of values = 1 in step 27, step id = 28  [28/121]
#   number of values = 1 in step 28, step id = 29  [29/121]
#   number of values = 1 in step 29, step id = 30  [30/121]
#   number of values = 1 in step 30, step id = 31  [31/121]
#   number of values = 1 in step 31, step id = 32  [32/121]
#   number of values = 1 in step 32, step id = 33  [33/121]
#   number of values = 1 in step 33, step id = 34  [34/121]
#   number of values = 1 in step 34, step id = 35  [35/121]
#   number of values = 1 in step 35, step id = 36  [36/121]
#   number of values = 1 in step 36, step id = 37  [37/121]
#   number of values = 1 in step 37, step id = 38  [38/121]
#   number of values = 1 in step 38, step id = 39  [39/121]
#   number of values = 1 in step 39, step id = 40  [40/121]
#   number of values = 1 in step 40, step id = 41  [41/121]
#   number of values = 1 in step 41, step id = 42  [42/121]
#   number of values = 1 in step 42, step id = 43  [43/121]
#   number of values = 1 in step 43, step id = 44  [44/121]
#   number of values = 1 in step 44, step id = 45  [45/121]
#   number of values = 1 in step 45, step id = 46  [46/121]
#   number of values = 1 in step 46, step id = 47  [47/121]
#   number of values = 1 in step 47, step id = 48  [48/121]
#   number of values = 1 in step 48, step id = 49  [49/121]
#   number of values = 1 in step 49, step id = 50  [50/121]
#   number of values = 1 in step 50, step id = 51  [51/121]
#   number of values = 1 in step 51, step id = 52  [52/121]
#   number of values = 1 in step 52, step id = 53  [53/121]
#   number of values = 1 in step 53, step id = 54  [54/121]
#   number of values = 1 in step 54, step id = 55  [55/121]
#   number of values = 1 in step 55, step id = 56  [56/121]
#   number of values = 1 in step 56, step id = 57  [57/121]
#   number of values = 1 in step 57, step id = 58  [58/121]
#   number of values = 1 in step 58, step id = 59  [59/121]
#   number of values = 1 in step 59, step id = 60  [60/121]
#   number of values = 1 in step 60, step id = 61  [61/121]
#   number of values = 1 in step 61, step id = 62  [62/121]
#   number of values = 1 in step 62, step id = 63  [63/121]
#   number of values = 1 in step 63, step id = 64  [64/121]
#   number of values = 1 in step 64, step id = 65  [65/121]
#   number of values = 1 in step 65, step id = 66  [66/121]
#   number of values = 1 in step 66, step id = 67  [67/121]
#   number of values = 1 in step 67, step id = 68  [68/121]
#   number of values = 1 in step 68, step id = 69  [69/121]
#   number of values = 1 in step 69, step id = 70  [70/121]
#   number of values = 1 in step 70, step id = 71  [71/121]
#   number of values = 1 in step 71, step id = 72  [72/121]
#   number of values = 1 in step 72, step id = 73  [73/121]
#   number of values = 1 in step 73, step id = 74  [74/121]
#   number of values = 1 in step 74, step id = 75  [75/121]
#   number of values = 1 in step 75, step id = 76  [76/121]
#   number of values = 1 in step 76, step id = 77  [77/121]
#   number of values = 1 in step 77, step id = 78  [78/121]
#   number of values = 1 in step 78, step id = 79  [79/121]
#   number of values = 1 in step 79, step id = 80  [80/121]
#   number of values = 1 in step 80, step id = 81  [81/121]
#   number of values = 1 in step 81, step id = 82  [82/121]
#   number of values = 1 in step 82, step id = 83  [83/121]
#   number of values = 1 in step 83, step id = 84  [84/121]
#   number of values = 1 in step 84, step id = 85  [85/121]
#   number of values = 1 in step 85, step id = 86  [86/121]
#   number of values = 1 in step 86, step id = 87  [87/121]
#   number of values = 1 in step 87, step id = 88  [88/121]
#   number of values = 1 in step 88, step id = 89  [89/121]
#   number of values = 1 in step 89, step id = 90  [90/121]
#   number of values = 1 in step 90, step id = 91  [91/121]
#   number of values = 1 in step 91, step id = 92  [92/121]
#   number of values = 1 in step 92, step id = 93  [93/121]
#   number of values = 1 in step 93, step id = 94  [94/121]
#   number of values = 1 in step 94, step id = 95  [95/121]
#   number of values = 1 in step 95, step id = 96  [96/121]
#   number of values = 1 in step 96, step id = 97  [97/121]
#   number of values = 1 in step 97, step id = 98  [98/121]
#   number of values = 1 in step 98, step id = 99  [99/121]
#   number of values = 1 in step 99, step id = 100  [100/121]
#   number of values = 1 in step 100, step id = 101  [101/121]
#   number of values = 1 in step 101, step id = 102  [102/121]
#   number of values = 1 in step 102, step id = 103  [103/121]
#   number of values = 1 in step 103, step id = 104  [104/121]
#   number of values = 1 in step 104, step id = 105  [105/121]
#   number of values = 1 in step 105, step id = 106  [106/121]
#   number of values = 1 in step 106, step id = 107  [107/121]
#   number of values = 1 in step 107, step id = 108  [108/121]
#   number of values = 1 in step 108, step id = 109  [109/121]
#   number of values = 1 in step 109, step id = 110  [110/121]
#   number of values = 1 in step 110, step id = 111  [111/121]
#   number of values = 1 in step 111, step id = 112  [112/121]
#   number of values = 1 in step 112, step id = 113  [113/121]
#   number of values = 1 in step 113, step id = 114  [114/121]
#   number of values = 1 in step 114, step id = 115  [115/121]
#   number of values = 1 in step 115, step id = 116  [116/121]
#   number of values = 1 in step 116, step id = 117  [117/121]
#   number of values = 1 in step 117, step id = 118  [118/121]
#   number of values = 1 in step 118, step id = 119  [119/121]
#   number of values = 1 in step 119, step id = 120  [120/121]
#   number of values = 1 in step 120, step id = 121  [121/121]
# reading destination geometry...
# Nastran Bulk Data Fast Readerd:\KangDH\Emlab_emach\tools\jmag\jplotReader\input.nas
#     start loading d:\KangDH\Emlab_emach\tools\jmag\jplotReader\input.nas
#     file size: 1818584[Bytes]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# output mesh length scale = 0.001 set by mm
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# Using num_threads(in setNextElemMt) = 8
# numelems = 17992
# Using num_threads(in setNextElemMt1) = 8
# numelems = 17992
# Using num_threads(in setModelSizeMt) = 8
#     get destination_model_thickness from source_model_thickness.  model thickness = 0.15
#   add destination_model_thickness to parameter.  model thickness = 0.15
# mapping (component = vector_potential)
#   source nodes = 14231, elements = 27274
#   destination nodes = 10511, elements = 17992
# mpfet progress rate : 23[%]
# doMotionConversion ...
#   componentIndex = 0, motion converting vector_potential
#   numStep = 121, valuePerLine = 3
#   component-key = vector_potential
#   map type = simple_node
#   source dimension = dim2
#   target dimension = dim2
#   CoordinateCompositionSetter  refOrigin= (0,0,0)
#   CoordinateCompositionSetter  refAxisX= (1,0,0)
#   CoordinateCompositionSetter  refAxisY= (0,1,0)
#   CoordinateCompositionSetter  refAxisZ= (0,0,1)
#   CoordinateCompositionSetter  srcCoordinateOrigin= (0,0,0)
#   CoordinateCompositionSetter  srcCoordinateAxisX= (1,0,0)
#   CoordinateCompositionSetter  srcCoordinateAxisY= (0,1,0)
#   CoordinateCompositionSetter  srcCoordinateAxisZ= (0,0,1)
#   coordinate conversion adopted
#   source mesh bounding box(max) = (0.23, 0.162635, 0)
#   source mesh bounding box(min) = (0, 0, 0)
#   destination mesh bounding box(max) = (0.2, 0.141421, 0)
#   destination mesh bounding box(min) = (0.0372913, 0, 0)
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# mpfet set size of map for src steps = 121
# change cash size per page : 400 (kb) -> 3305 (kb)
# using num_threads(Mapper::SetMesh) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# Using num_threads(in FindPairElementsInMaterialsContinuously1) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# using num_threads(Mapper::SetMesh) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# Using num_threads(in FFindPairElementsInMaterialsContinuously2) = 8
# Using num_threads(in FindMaterialsWithVolume) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
#   node mapping info : temporary stored the destination part ids in 1st mapping.
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = 0.0137497
#   elapsed time for mapping (simple_node) at step 0 : 0
# mpfet progress rate : 23[%]
# change cash size per page : 3305.78 (kb) -> 3305.78 (kb)
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 1 : 0
# mpfet progress rate : 24[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 2 : 0
# mpfet progress rate : 24[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 3 : 0
# mpfet progress rate : 25[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 4 : 0
# mpfet progress rate : 25[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 5 : 0
# mpfet progress rate : 26[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 6 : 0
# mpfet progress rate : 26[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 7 : 0
# mpfet progress rate : 27[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 8 : 0
# mpfet progress rate : 27[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 9 : 0
# mpfet progress rate : 28[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 10 : 0
# mpfet progress rate : 28[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 11 : 0
# mpfet progress rate : 29[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 12 : 0
# mpfet progress rate : 29[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 13 : 0
# mpfet progress rate : 30[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 14 : 0
# mpfet progress rate : 30[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 15 : 0
# mpfet progress rate : 31[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 16 : 0
# mpfet progress rate : 31[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 17 : 0
# mpfet progress rate : 32[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 18 : 0
# mpfet progress rate : 32[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 19 : 0
# mpfet progress rate : 33[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 20 : 0
# mpfet progress rate : 33[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 21 : 1
# mpfet progress rate : 34[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 22 : 0
# mpfet progress rate : 34[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 23 : 0
# mpfet progress rate : 35[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 24 : 0
# mpfet progress rate : 35[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 25 : 0
# mpfet progress rate : 36[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 26 : 0
# mpfet progress rate : 36[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 27 : 0
# mpfet progress rate : 37[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 28 : 0
# mpfet progress rate : 37[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 29 : 0
# mpfet progress rate : 38[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 30 : 0
# mpfet progress rate : 38[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 31 : 0
# mpfet progress rate : 39[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 32 : 0
# mpfet progress rate : 39[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 33 : 0
# mpfet progress rate : 40[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 34 : 0
# mpfet progress rate : 40[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 35 : 0
# mpfet progress rate : 41[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 36 : 0
# mpfet progress rate : 41[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 37 : 0
# mpfet progress rate : 42[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 38 : 0
# mpfet progress rate : 42[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 39 : 0
# mpfet progress rate : 43[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 40 : 0
# mpfet progress rate : 43[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 41 : 0
# mpfet progress rate : 44[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 42 : 0
# mpfet progress rate : 44[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 43 : 0
# mpfet progress rate : 45[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 44 : 0
# mpfet progress rate : 45[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 45 : 0
# mpfet progress rate : 46[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 46 : 0
# mpfet progress rate : 46[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 47 : 0
# mpfet progress rate : 47[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 48 : 0
# mpfet progress rate : 47[%]
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# flg map central node = 1 set by input parameter.
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# number of using threads in SimpleNodeMapRunner = 8
# node mapping result : mapped values = 1382
# node mapping tolerance to search = -1
#   elapsed time for mapping (simple_node) at step 49 : 0
# ...
#   current number of steps by step value = 65
#   step-index=65, key = vector_potential, step=66
#   add new step in order by step value : stepNumber = 66, stepValue=0.000451389
#   current number of steps by step value = 66
#   step-index=66, key = vector_potential, step=67
#   add new step in order by step value : stepNumber = 67, stepValue=0.000458333
#   current number of steps by step value = 67
#   step-index=67, key = vector_potential, step=68
#   add new step in order by step value : stepNumber = 68, stepValue=0.000465278
#   current number of steps by step value = 68
#   step-index=68, key = vector_potential, step=69
#   add new step in order by step value : stepNumber = 69, stepValue=0.000472222
#   current number of steps by step value = 69
#   step-index=69, key = vector_potential, step=70
#   add new step in order by step value : stepNumber = 70, stepValue=0.000479167
#   current number of steps by step value = 70
#   step-index=70, key = vector_potential, step=71
#   add new step in order by step value : stepNumber = 71, stepValue=0.000486111
#   current number of steps by step value = 71
#   step-index=71, key = vector_potential, step=72
#   add new step in order by step value : stepNumber = 72, stepValue=0.000493056
#   current number of steps by step value = 72
#   step-index=72, key = vector_potential, step=73
#   add new step in order by step value : stepNumber = 73, stepValue=0.0005
#   current number of steps by step value = 73
#   step-index=73, key = vector_potential, step=74
#   add new step in order by step value : stepNumber = 74, stepValue=0.000506944
#   current number of steps by step value = 74
#   step-index=74, key = vector_potential, step=75
#   add new step in order by step value : stepNumber = 75, stepValue=0.000513889
#   current number of steps by step value = 75
#   step-index=75, key = vector_potential, step=76
#   add new step in order by step value : stepNumber = 76, stepValue=0.000520833
#   current number of steps by step value = 76
#   step-index=76, key = vector_potential, step=77
#   add new step in order by step value : stepNumber = 77, stepValue=0.000527778
#   current number of steps by step value = 77
#   step-index=77, key = vector_potential, step=78
#   add new step in order by step value : stepNumber = 78, stepValue=0.000534722
#   current number of steps by step value = 78
#   step-index=78, key = vector_potential, step=79
#   add new step in order by step value : stepNumber = 79, stepValue=0.000541667
#   current number of steps by step value = 79
#   step-index=79, key = vector_potential, step=80
#   add new step in order by step value : stepNumber = 80, stepValue=0.000548611
#   current number of steps by step value = 80
#   step-index=80, key = vector_potential, step=81
#   add new step in order by step value : stepNumber = 81, stepValue=0.000555556
#   current number of steps by step value = 81
#   step-index=81, key = vector_potential, step=82
#   add new step in order by step value : stepNumber = 82, stepValue=0.0005625
#   current number of steps by step value = 82
#   step-index=82, key = vector_potential, step=83
#   add new step in order by step value : stepNumber = 83, stepValue=0.000569444
#   current number of steps by step value = 83
#   step-index=83, key = vector_potential, step=84
#   add new step in order by step value : stepNumber = 84, stepValue=0.000576389
#   current number of steps by step value = 84
#   step-index=84, key = vector_potential, step=85
#   add new step in order by step value : stepNumber = 85, stepValue=0.000583333
#   current number of steps by step value = 85
#   step-index=85, key = vector_potential, step=86
#   add new step in order by step value : stepNumber = 86, stepValue=0.000590278
#   current number of steps by step value = 86
#   step-index=86, key = vector_potential, step=87
#   add new step in order by step value : stepNumber = 87, stepValue=0.000597222
#   current number of steps by step value = 87
#   step-index=87, key = vector_potential, step=88
#   add new step in order by step value : stepNumber = 88, stepValue=0.000604167
#   current number of steps by step value = 88
#   step-index=88, key = vector_potential, step=89
#   add new step in order by step value : stepNumber = 89, stepValue=0.000611111
#   current number of steps by step value = 89
#   step-index=89, key = vector_potential, step=90
#   add new step in order by step value : stepNumber = 90, stepValue=0.000618056
#   current number of steps by step value = 90
#   step-index=90, key = vector_potential, step=91
#   add new step in order by step value : stepNumber = 91, stepValue=0.000625
#   current number of steps by step value = 91
#   step-index=91, key = vector_potential, step=92
#   add new step in order by step value : stepNumber = 92, stepValue=0.000631944
#   current number of steps by step value = 92
#   step-index=92, key = vector_potential, step=93
#   add new step in order by step value : stepNumber = 93, stepValue=0.000638889
#   current number of steps by step value = 93
#   step-index=93, key = vector_potential, step=94
#   add new step in order by step value : stepNumber = 94, stepValue=0.000645833
#   current number of steps by step value = 94
#   step-index=94, key = vector_potential, step=95
#   add new step in order by step value : stepNumber = 95, stepValue=0.000652778
#   current number of steps by step value = 95
#   step-index=95, key = vector_potential, step=96
#   add new step in order by step value : stepNumber = 96, stepValue=0.000659722
#   current number of steps by step value = 96
#   step-index=96, key = vector_potential, step=97
#   add new step in order by step value : stepNumber = 97, stepValue=0.000666667
#   current number of steps by step value = 97
#   step-index=97, key = vector_potential, step=98
#   add new step in order by step value : stepNumber = 98, stepValue=0.000673611
#   current number of steps by step value = 98
#   step-index=98, key = vector_potential, step=99
#   add new step in order by step value : stepNumber = 99, stepValue=0.000680556
#   current number of steps by step value = 99
#   step-index=99, key = vector_potential, step=100
#   add new step in order by step value : stepNumber = 100, stepValue=0.0006875
#   current number of steps by step value = 100
#   step-index=100, key = vector_potential, step=101
#   add new step in order by step value : stepNumber = 101, stepValue=0.000694444
#   current number of steps by step value = 101
#   step-index=101, key = vector_potential, step=102
#   add new step in order by step value : stepNumber = 102, stepValue=0.000701389
#   current number of steps by step value = 102
#   step-index=102, key = vector_potential, step=103
#   add new step in order by step value : stepNumber = 103, stepValue=0.000708333
#   current number of steps by step value = 103
#   step-index=103, key = vector_potential, step=104
#   add new step in order by step value : stepNumber = 104, stepValue=0.000715278
#   current number of steps by step value = 104
#   step-index=104, key = vector_potential, step=105
#   add new step in order by step value : stepNumber = 105, stepValue=0.000722222
#   current number of steps by step value = 105
#   step-index=105, key = vector_potential, step=106
#   add new step in order by step value : stepNumber = 106, stepValue=0.000729167
#   current number of steps by step value = 106
#   step-index=106, key = vector_potential, step=107
#   add new step in order by step value : stepNumber = 107, stepValue=0.000736111
#   current number of steps by step value = 107
#   step-index=107, key = vector_potential, step=108
#   add new step in order by step value : stepNumber = 108, stepValue=0.000743056
#   current number of steps by step value = 108
#   step-index=108, key = vector_potential, step=109
#   add new step in order by step value : stepNumber = 109, stepValue=0.00075
#   current number of steps by step value = 109
#   step-index=109, key = vector_potential, step=110
#   add new step in order by step value : stepNumber = 110, stepValue=0.000756944
#   current number of steps by step value = 110
#   step-index=110, key = vector_potential, step=111
#   add new step in order by step value : stepNumber = 111, stepValue=0.000763889
#   current number of steps by step value = 111
#   step-index=111, key = vector_potential, step=112
#   add new step in order by step value : stepNumber = 112, stepValue=0.000770833
#   current number of steps by step value = 112
#   step-index=112, key = vector_potential, step=113
#   add new step in order by step value : stepNumber = 113, stepValue=0.000777778
#   current number of steps by step value = 113
#   step-index=113, key = vector_potential, step=114
#   add new step in order by step value : stepNumber = 114, stepValue=0.000784722
#   current number of steps by step value = 114
#   step-index=114, key = vector_potential, step=115
#   add new step in order by step value : stepNumber = 115, stepValue=0.000791667
#   current number of steps by step value = 115
#   step-index=115, key = vector_potential, step=116
#   add new step in order by step value : stepNumber = 116, stepValue=0.000798611
#   current number of steps by step value = 116
#   step-index=116, key = vector_potential, step=117
#   add new step in order by step value : stepNumber = 117, stepValue=0.000805556
#   current number of steps by step value = 117
#   step-index=117, key = vector_potential, step=118
#   add new step in order by step value : stepNumber = 118, stepValue=0.0008125
#   current number of steps by step value = 118
#   step-index=118, key = vector_potential, step=119
#   add new step in order by step value : stepNumber = 119, stepValue=0.000819444
#   current number of steps by step value = 119
#   step-index=119, key = vector_potential, step=120
#   add new step in order by step value : stepNumber = 120, stepValue=0.000826389
#   current number of steps by step value = 120
#   step-index=120, key = vector_potential, step=121
#   add new step in order by step value : stepNumber = 121, stepValue=0.000833333
#   current number of steps by step value = 121
# output mesh length scale = 0.001 set by mm
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: no sort
#   PostProcess: page in count: 121
#   PostProcess: page out count: 0
# start to write results by csv general value writer
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# physical cores(Mapper::GetOmpNumThreads) = 18
# set num_threads(Mapper::GetOmpNumThreads) = 8
# finish to write results by csv general value writer
# mpfet progress rate : 92[%]
# mpfet progress rate : 92[%]
# Checking for file
# Checking for crash
# File checker time = 3
# Condensing file, blocks = 5
# finish to pull references of the general interface analysis runner
#   calling TLicenseControl::CheckInAll().
#   called TLicenseControl::CheckInAll().
# Could not find temporary restart step file: d:\KangDH\Emlab_emach\tools\jmag\jplotReader\restartstep
# Could not find temporary restart step file: d:\KangDH\Emlab_emach\tools\jmag\jplotReader\restartstep
# code : 60005
# JMAG-Designer Version Number
# PREPOST_VERSION: JMAG-Designer(x64) 23.1.01zx
#
# mpfet progress rate : 100[%]
#   callbackFuncForAtExit() terminationType=0
# is_extend_3d 0
# is_extend_full 0
#   The output mesh model dimension = 2
# UTF-8 file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case28/Designer.jplot
# S-JIS file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case28/Designer.jplot
# UTF-8 file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case1/Designer.jplot
# S-JIS file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case1/Designer.jplot
# UTF-8 file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case28/Designer.jplot
# S-JIS file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case28/Designer.jplot
# UTF-8 file name = D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools/MS_Conductor_C28.csv
# S-JIS file name = D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools/MS_Conductor_C28.csv
# UTF-8 file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case1/Database
# S-JIS file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case1/Database
# UTF-8 file name = Designer
# S-JIS file name = Designer
# UTF-8 file name =
# S-JIS file name =
# UTF-8 file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case1/Designer.jplot
# S-JIS file name = E:/KDH/e10/MSConductorModel/e10MS_ConductorModel.jfiles/e10MS_ConductorModel~6/e10MS_ConductorModel_SCL_Load~13/Case1/Designer.jplot
# filename = E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case1\Designer.jplot
# Writing xml file (D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools\MS_Conductor_C28_jcoupled.xml)...End
# WARNING
# code : 46021
# Reset InsDir=InsDir=C:\Program Files\JMAG-Designer23.1
# ""C:\Program Files\JMAG-Designer23.1\JCoupled.exe" -mode=control "D:/KangDH/Emlab_emach/mlxperPJT/JEET/From38100/MPtools\MS_Conductor_C28_jcoupled.xml" -mpfet"
# License Check In

# %%
jplot_file_path=current_jplot_path

# %%
reader = JplotReader.jplotOpen(jplot_file_path.encode('utf-8'))

# %%
element_centers= jpr.readElementCenters(reader)

# %%
JmagPJTPath, NODEIDmat_file_path=jpr.getJmagPJTPathAndMatPath(current_jplot_path,'NodeID')
try:
    # .mat 파일에서 partID 목록 읽어오기
    mat_data = sio.loadmat(NODEIDmat_file_path)
    NodeIDs= mat_data['NodeID'].flatten()  # partIDs를 1D로 변환 (ndarray)
except Exception as e:
    print(f"Error loading .mat file: {e}")

# %%
print(NodeIDs

# %%
JmagResultPath=   current_jplot_path
type2Find='NodeID'
import re

# JmagResultName 추출
JmagResultName = os.path.basename(JmagResultPath)  # 경로에서 파일명 추출

# 확장자 ".jfiles" 이전의 경로 추출
JmagResultDIR = re.sub(r'\.jfiles.*$', '', JmagResultPath)  # ".jfiles" 이전 부분만 추출

# .jproj 파일 경로 생성
JmagPJTDIR, JmagPJTName = os.path.split(JmagResultDIR)  # 디렉토리 및 이름 분리
JmagPJTPath = os.path.join(JmagPJTDIR, f"{JmagPJTName}.jproj")  # .jproj 파일 경로 생성

# 동일한 구조의 .mat 파일 경로 생성
mat_file_path = os.path.join(JmagPJTDIR, f"{JmagPJTName}{type2Find}.mat")  # .mat 파일 경로 생성

NODEIDmat_file_path=mat_file_path
# JmagPJTPath, NODEIDmat_file_path=jpr.getJmagPJTPathAndMatPath(jplot_file_path,'NodeID')
    # .mat 파일에서 partID 목록 읽어오기
mat_data = sio.loadmat(NODEIDmat_file_path)
NodeIDs= mat_data['NodeID'].flatten()  # partIDs를 1D로 변환 (ndarray)

filtered_ids_set = set(NodeIDs)  # set으로 변환하여 검색 최적화

component_data=jpr.readComponentData(reader,11005, 121,filtered_ids_set)
component_data

# %%
jplot_file_path = r'F:\KDH\KDH\SCL_e10_WTPM_PatternD_R1_16kMap.jfiles\SC_e10_WirePeriodic~9\SC_e10_WirePeriodic_Load_16k_rough~27\Case26\Designer.jplot'

JmagPJTPath, mat_file_path=jpr.getJmagPJTPathAndMatPath(jplot_file_path)

# .mat 파일에서 partID 목록 읽어오기
mat_data = sio.loadmat(mat_file_path)
part_ids = mat_data['partID'].flatten()  # partIDs를 1D로 변환 (ndarray)
import numpy as np
# 첫 번째(인덱스 0)와 두 번째(인덱스 1) 값을 삭제
part_ids = np.delete(part_ids, [0,2])

filtered_element_ids = []

for center in element_centers:
    part_id = center[1]  # center[1]이 partID를 의미함
    if part_id in part_ids:  # part_ids에 포함된 partID만 필터링
        # print(part_id)
        filtered_element_ids.append(center[0])  # 해당 요소의 element ID 추가
    
 # Read element centers
element_centers=[]
element_centers= jpr.readElementCenters(reader)
filtered_element_ids = jpr.filterElementCentersByPartID(element_centers, part_ids)
filtered_element_ids_set = set(filtered_element_ids)  # set으로 변환하여 검색 최적화
component_data=jpr.readComponentData(reader,16001, 241,filtered_element_ids_set)

# %%
process_case(28, jplot_file_path, postkey_id)

# %%
for case_number in range(1, 31):
    process_case(case_number, SCL_TS_16kpath, postkey_id)

# %%
# REFMS120Steppath = r"D:\KangDH\Thesis\e10\JMAG\MSConductorModel\e10MS_ConductorModel_REF.jfiles\e10MS_ConductorModel_REF~7\e10MS_ConductorModel_REF_Load~16\Case{}\Designer.jplot"
SCL_jplot_path = r"E:\KDH\e10\MSConductorModel\e10MS_ConductorModel.jfiles\e10MS_ConductorModel~6\e10MS_ConductorModel_SCL_Load~13\Case{}\Designer.jplot"
# SCL_TS_16kpath = r'F:\KDH\KDH\SCL_e10_WTPM_PatternD_R1_16kMap.jfiles\SC_e10_WirePeriodic~9\SC_e10_WirePeriodic_Load_16k_rough~27\Case{}\Designer.jplot'
forPath=SCL_jplot_path
# SCL_Ts_4kpath=r'F:\KDH\KDH\SCL_e10_WTPM_PatternD_R1_4k.jfiles\SC_e10_WirePeriodic~9\SC_e10_WirePeriodic_Load_4k_rough~26'
# SCL_Ts_4kpath=r'F:\KDH\KDH\SCL_e10_WTPM_PatternD_R1_4k.jfiles\SC_e10_WirePeriodic~9\SC_e10_WirePeriodic_Load_4k_rough~26\Case{}\Designer.jplot'
# forPath=SCL_Ts_4kpath
# SCLTS_18kPath=r'F:\KDH\KDH\SCL_e10_WTPM_PatternD_R1_18kMap.jfiles\SC_e10_WirePeriodic~9\SC_e10_WirePeriodic_Load_18k_rough~27\Case{}\Designer.jplot'
# SCLMS120Steppath=r'D:\KangDH\Thesis\e10\JMAG\MSConductorModel\e10MS_ConductorModel_SCL.jfiles\e10MS_ConductorModel_SCL~8\e10MS_ConductorModel_SCL_Load_240Step~21\Case{}\Designer.jplot'
# FqSCLMSFPpath=r'D:\KangDH\Thesis\e10\JMAG\SCL_e10_WTPM_PatternD_R1_FqMap_MSFp.jfiles\SC_e10_WirePeriodic~9\SC_e10_WirePeriodic_Load_FqWithShiftAvgDiffMu~33\Case{}\Designer.jplot'
# MQS_jplot_path=r"D:\KangDH\Thesis\e10\JMAG\REF_e10_WTPM_PatternD_R1_18k.jfiles\ref_e10_WirePeriodic~1\ref_e10_WirePeriodic_Load_18k_rgh~32\Case{}\Designer.jplot"
# SCL9kRPMPath=r'D:\KangDH\Thesis\e10\JMAG\SCL_e10_WTPM_PatternD_R1_9kMap.jfiles\SC_e10_WirePeriodic~9\SC_e10_WirePeriodic_Load_9k_rough240steps~28\Case{}\Designer.jplot'

    # postkey_id = 11005 MVP
# 19501 Fq
# 16001
# Case1부터 Case30까지 처리
for case_number in range(28,29):
    # 각 case 번호에 따라 경로 생성
    current_jplot_path = forPath.format(case_number)
    postkey_id =11005 
    jpr.main(current_jplot_path,1,121,postkey_id)

# %%
# base_jplot_path = r"D:\KangDH\Thesis\e10\JMAG\MSConductorModel\e10MS_ConductorModel_REF.jfiles\e10MS_ConductorModel_REF~7\e10MS_ConductorModel_REF_Load~16\Case{}\Designer.jplot"
# base_jplot_path=r"D:\KangDH\Thesis\e10\JMAG\REF_e10_WTPM_PatternD_R1_18k.jfiles\ref_e10_WirePeriodic~1\ref_e10_WirePeriodic_Load_18k_rgh~32\Case{}\Designer.jplot"
# Case1부터 Case30까지 처리
# for case_number in range(1, 31):
    # 각 case 번호에 따라 경로 생성
 # TS REF
# current_jplot_path=   r"D:\KangDH\Thesis\e10\JMAG\REF_e10_WTPM_PatternD_R1_18kre_v1.jfiles\ref_e10_WirePeriodic~1\ref_e10_WirePeriodic_Load_18k_rgh~32\Case28\Designer.jplot"
 # MS REF
# current_jplot_path=r'D:\KangDH\Thesis\e10\JMAG\MSConductorModel\e10MS_ConductorModel_REF.jfiles\e10MS_ConductorModel_REF~7\e10MS_ConductorModel_REF_Load_240Step~20\Case1\Designer.jplot'

# SCL TS
# current_jplot_path=r'D:\KangDH\Thesis\e10\JMAG\SCL_e10_WTPM_PatternD_R1_18kMap.jfiles\SC_e10_WirePeriodic~9\SC_e10_WirePeriodic_Load_18k_rough240steps~28\Case2\Designer.jplot'
# SCL MS
current_jplot_path=r'D:\KangDH\Thesis\e10\JMAG\MSConductorModel\e10MS_ConductorModel_SCL.jfiles\e10MS_ConductorModel_SCL~8\e10MS_ConductorModel_SCL_Load_240Step~21\Case2\Designer.jplot'

# current_jplot_path = base_jplot_path.format(28)
postkey_id = 16001
current_jplot_path
jpr.main(current_jplot_path, 240,postkey_id)

# %% [markdown]
# # WIP Part별 그룹

# %%
import sys
import os
import ctypes
import scipy.io as sio
import re

# mainJplotReader.py 파일이 있는 경로를 추가
module_path = r'C:\Program Files\JMAG-Designer23.1\Tools\JPlotReader\samples\Python'
if module_path not in sys.path:
    sys.path.append(module_path)

# 모듈 가져오기
import mainJplotReader as jpr

# savePartGroupedDataToMat 함수: 파트별로 데이터를 그룹핑하여 mat 파일로 저장
def savePartGroupedDataToMat(part_grouped_data, output_file_name):
    """
    파트별로 그룹핑된 데이터를 .mat 파일로 저장하는 함수.
    
    Args:
        part_grouped_data (dict): 파트 이름별로 그룹핑된 데이터.
        output_file_name (str): 저장할 mat 파일 이름.
    """
    mat_data = {}
    
    # 파트 그룹핑된 데이터를 mat 파일 형식에 맞게 저장
    for part_name, data in part_grouped_data.items():
        # 파트 이름의 특수문자 제거 및 길이 제한
        valid_part_name = re.sub(r'\W+', '_', part_name)
        mat_data[valid_part_name] = data
    
    # .mat 파일로 저장
    sio.savemat(output_file_name, mat_data)
    print(f"파트별 데이터가 {output_file_name}으로 저장되었습니다.")

# main 함수 수정
def main(jplot_file_path, totalSteps, postkey_id):
    # JplotReader 열기
    reader = jpr.JplotReader.jplotOpen(jplot_file_path.encode('utf-8'))

    if reader is None:
        print(f"Cannot open file: {jplot_file_path}")
        return
    
    part_grouped_data = {}
    
    # 파트 정보 읽기 (파트 ID와 이름을 가져와서 데이터 그룹핑에 사용)
    numParts = jpr.JplotReader.jplotCountParts(reader)
    part_info = {}
    for i in range(numParts):
        part_id = ctypes.c_int()
        name_buffer = ctypes.create_string_buffer(256)  # 파트 이름을 저장할 버퍼
        jpr.JplotReader.jplotGetPartIdTitle(reader, i, ctypes.byref(part_id), name_buffer, 256)
        part_name = name_buffer.value.decode('utf-8')
        part_info[part_id.value] = part_name
    
    # 요소 중심 읽기
    element_centers = jpr.readElementCenters(reader)

    # 각 스텝에 대한 컴포넌트 데이터 읽기 및 파트 이름에 따라 그룹핑
    for stepIndex in range(1, totalSteps + 1):
        component_data = jpr.readComponentData(reader, postkey_id, stepIndex)
        
        for element in component_data:
            element_id, value1, value2, value3 = element
            part_id = None
            
            # 요소 ID를 통해 part_id 찾기
            for center in element_centers:
                if center[0] == element_id:  # center[0]은 element_id
                    part_id = center[1]  # center[1]은 part_id
                    break
            
            # 파트 이름으로 데이터 그룹핑
            if part_id in part_info:
                part_name = part_info[part_id]
                if part_name not in part_grouped_data:
                    part_grouped_data[part_name] = []
                part_grouped_data[part_name].append([element_id, value1, value2, value3])
    
    # JplotReader 닫기
    jpr.JplotReader.jplotClose(reader)

    # 파일 경로에서 Case 번호 및 로드 이름 추출
    case_match = re.search(r"\\(Case\d+)", jplot_file_path)
    case_name = case_match.group(1)  # 'Case1', 'Case2' 등의 Case 번호 추출

    load_name_match = re.search(r"\\([^\\]+)\\Case\d+", jplot_file_path)
    if load_name_match:
        load_name = load_name_match.group(1)  # "Case" 이전의 폴더 이름
    else:
        load_name = "UnknownLoad"  # 추출 실패 시 기본값

    # 파일 이름 생성
    if postkey_id == 16001:
         output_file_name = f"{load_name}_{case_name}_MagB_PartGrouped.mat"
    elif postkey_id == 11005:
        output_file_name = f"{load_name}_{case_name}_MagA_PartGrouped.mat"

    # 그룹핑된 데이터를 .mat 파일로 저장
    savePartGroupedDataToMat(part_grouped_data, output_file_name)

    print(f"Data saved to {output_file_name}")

# %%
# base_jplot_path = r"D:\KangDH\Thesis\e10\JMAG\MSConductorModel\e10MS_ConductorModel_REF.jfiles\e10MS_ConductorModel_REF~7\e10MS_ConductorModel_REF_Load~16\Case{}\Designer.jplot"
base_jplot_path=r"D:\KangDH\Thesis\e10\JMAG\REF_e10_WTPM_PatternD_R1_18k.jfiles\ref_e10_WirePeriodic~1\ref_e10_WirePeriodic_Load_18k_rgh~32\Case{}\Designer.jplot"
# Case1부터 Case30까지 처리
# for case_number in range(1, 31):
    # 각 case 번호에 따라 경로 생성
current_jplot_path = base_jplot_path.format(28)
postkey_id = 16001
current_jplot_path
main(current_jplot_path, 241,postkey_id)

# %% [markdown]
# # Manual JPlotReader Call

# %%
import ctypes
import sys

from JplotReader import JplotReader as jr

def main():
    if len(sys.argv) != 2:
        print("Parameter should be path to JPLOT file")
        sys.exit(1)

    # Open JplotReader for the given path
    reader = JplotReader.jplotOpen(sys.argv[1].encode('utf-8'))

    if reader is None:
        print("Cannot open file: {:s}".format(sys.argv[1]))
        sys.exit(1)
    
    # Read nodes
    readNodes(reader)

    # Read element centers
    readElementCenters(reader)

    # Read nodal displacements
    readNodalDisplacements(reader)

    # Read element center displacements
    readElementCenterDisplacements(reader)

    # Read component data
    readComponentData(reader)

    # Close JplotReader when finished
    JplotReader.jplotClose(reader)

    sys.exit(0)

def readNodes(reader):
    nodeCount = JplotReader.jplotCountNodes(reader) # Number of nodes
    print ("Number of nodes: {:d}".format(nodeCount))

    JplotReader.jplotStartPopNode(reader) # Prepare reader to pop nodes
    for i in range(nodeCount):
        id = ctypes.c_int() # Node ID
        x = ctypes.c_double() # Coordinates of node
        y = ctypes.c_double()
        z = ctypes.c_double()
        JplotReader.jplotPopNode(reader, id, x, y, z) # Pop node off stack and get its data
        print("Id: {:d}, x: {:f}, y: {:f}, z: {:f}".format(id.value, x.value, y.value, z.value))

    JplotReader.jplotEndPopNode(reader) # End popping of nodes

def readElementCenters(reader):
    elementCount = JplotReader.jplotCountElements(reader) # Number of elements
    print ("Number of elements: {:d}".format(elementCount))

    JplotReader.jplotStartPopElementCenter(reader) # Prepare reader to pop elements
    for i in range(elementCount):
        id = ctypes.c_int() # Element ID
        partId = ctypes.c_int() # Material ID
        eleType = ctypes.c_int() # Shape type of element
        x = ctypes.c_double() # Coordinates of center of element
        y = ctypes.c_double()
        z = ctypes.c_double()
        area = ctypes.c_double() # Area/volume of element
        JplotReader.jplotPopElementCenter(reader, id, partId, eleType, x, y, z, area) # Pop element off stack and get its data
        print("Id: {:d}, Part Id: {:d}, Element type: {:d}, x: {:f}, y: {:f}, z: {:f}, area: {:f}".format(id.value, partId.value, eleType.value, x.value, y.value, z.value, area.value))

    JplotReader.jplotEndPopElementCenter(reader) # End popping of elements

def readNodalDisplacements(reader):
    step = 1 # Step to read
    displacementCount = JplotReader.jplotCountNodalDisplacements(reader, step) # Number of nodal displacements
    print("Number of nodal displacements: {:d}".format(displacementCount))

    JplotReader.jplotStartPopNodalDisplacement(reader, step) # Prepare reader to pop nodal displacements
    for i in range(displacementCount):
        id = ctypes.c_int() # Node ID
        dx = ctypes.c_double() # Change in node position (displacement)
        dy = ctypes.c_double()
        dz = ctypes.c_double()
        JplotReader.jplotPopNodalDisplacement(reader, id, dx, dy, dz) # Pop nodal displacement off stack and get its data
        print("Id: {:d}, dx: {:f}, dy: {:f}, dz: {:f}".format(id.value, dx.value, dy.value, dz.value))

    JplotReader.jplotEndPopNodalDisplacement(reader) # End popping of nodal displacements

def readElementCenterDisplacements(reader):
    step = 1 # Step to read
    displacementCount = JplotReader.jplotCountElementCenterDisplacements(reader, step) # Number of element center displacements
    print("Number of element center displacements: {:d}".format(displacementCount))

    JplotReader.jplotStartPopElementCenterDisplacements(reader, step) # Prepare reader to pop element center displacements
    for i in range(displacementCount):
        id = ctypes.c_int() # Element ID
        dx = ctypes.c_double() # Change in element center position (displacement)
        dy = ctypes.c_double()
        dz = ctypes.c_double()
        JplotReader.jplotPopElementCenterDisplacement(reader, id, dx, dy, dz) # Pop element off stack and get its data
        print("Id: {:d}, dx: {:f}, dy: {:f}, dz: {:f}".format(id.value, dx.value, dy.value, dz.value))

    JplotReader.jplotEndPopElementCenterDisplacement(reader) # End popping of element center displacements

def readComponentData(reader):
    step = 1 # Step to read
    magneticFluxDensity = 16001 # Component key to read

    componentReader = JplotReader.jplotCreateComponentReader(reader, step, magneticFluxDensity) # Create component reader object
    if componentReader is None: # Check that component reader was properly created with valid values
        return
    
    componentCount = JplotReader.jplotCountComponents(componentReader) # Number of component data points
    print("Number of components: {:d}".format(componentCount))

    JplotReader.jplotStartPopComponent(componentReader) # Prepare component reader to pop component data
    for i in range(componentCount):
        id = ctypes.c_int()
        values = (ctypes.c_double * 3)() # Component values
        JplotReader.jplotPopComponent(componentReader, id, values) # Pop element off stack and get component data
        print("Id: {:d}, {:f}, {:f}, {:f}".format(id.value, values[0], values[1], values[2]))
    
    JplotReader.jplotEndPopComponent(componentReader) # End popping of component data
    JplotReader.jplotDeleteComponentReader(componentReader) # Delete component reader when done using

# %% [markdown]
# ## Open Reader n getPartID

# %%
reader = jr.jplotOpen(current_jplot_path.encode('utf-8'))

# %%
NumPart=jr.jplotCountParts(reader)

# %%
# 파트 ID와 이름을 저장할 변수 정의
part_id = ctypes.c_int()  # 파트 ID 저장
name_buffer_size = 256    # 파트 이름을 저장할 버퍼 크기
name_buffer = ctypes.create_string_buffer(name_buffer_size)  # 파트 이름 저장을 위한 버퍼

# 파트 인덱스 설정 (예시로 0 사용)
part_index = 1

# jplotGetPartIdTitle 함수 호출
jr.jplotGetPartIdTitle(reader, part_index, ctypes.byref(part_id), name_buffer, name_buffer_size)

# %%
# 파트 목록 저장 리스트
part_name_list = []

# part_index를 증가시키며 반복적으로 조회
part_index = 0

while True:
    # 파트 ID 저장을 위한 변수
    part_id = ctypes.c_int()

    # jplotGetPartIdTitle 함수 호출
    jr.jplotGetPartIdTitle(reader, part_index, ctypes.byref(part_id), name_buffer, name_buffer_size)

    # name_buffer에 저장된 값 확인
    part_name = name_buffer.value.decode('utf-8')

    # part_name이 비어 있으면 더 이상 유효한 파트가 없다는 의미
    if part_name == '':
        break

    # 파트 이름 목록에 추가
    part_name_list.append(part_name.strip())

    # 다음 파트를 조회하기 위해 part_index 증가
    part_index += 1

# 결과 출력
print("Part Name List:")
for i, name in enumerate(part_name_list):
    print(f"Part {i+1}: {name}")

# %%
readComponentData

# %%
readElementCenters(reader)

# %% [markdown]
# # J calc From MVP

# %%
JplotReader.main(jplot_file_path,121)

# %%
import ctypes
import scipy.io as sio
from JplotReader import JplotReader
import os
import re

def main(jplot_file_path, totalSteps):
    # Open JplotReader for the given path
    reader = JplotReader.jplotOpen(jplot_file_path.encode('utf-8'))

    if reader is None:
        print(f"Cannot open file: {jplot_file_path}")
        return
    
    data = {}
    
    # Read nodes
    data['nodes'] = readNodes(reader)

    # Read element centers
    data['element_centers'] = readElementCenters(reader)

    # Read nodal displacements
    data['nodal_displacements'] = readNodalDisplacements(reader)

    # Read element center displacements
    data['element_center_displacements'] = readElementCenterDisplacements(reader)
    
    # Read component data for each step
    for stepIndex in range(1, totalSteps+1):
        data[f'MagB_{stepIndex}'] = readComponentData(reader, 16001, stepIndex)
        data[f'MagA_{stepIndex}'] = readComponentData(reader, 11005, stepIndex)

    # Close JplotReader when finished
    JplotReader.jplotClose(reader)

    # Extract Case number and load name from the file path
    case_match = re.search(r"\\(Case\d+)", jplot_file_path)
    case_name = case_match.group(1)  # Extract the 'Case1', 'Case2', etc.

    # Extract the folder before "Case" to get the load name
    load_name_match = re.search(r"\\([^\\]+)\\Case\d+", jplot_file_path)
    if load_name_match:
        load_name = load_name_match.group(1)  # Folder name just before "Case"
    else:
        load_name = "UnknownLoad"  # Default name if extraction fails

    # Create the output file name using the extracted parts
    output_file_name = f"{load_name}_{case_name}.mat"

    # Save all data to .mat file with the new name
    sio.savemat(output_file_name, data)

    print(f"Data saved to {output_file_name}")

# %% [markdown]
# # Export MQS B
