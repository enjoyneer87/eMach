# %%
import sys
from pathlib import Path

# eMach 루트(EveryMotor)를 path에 추가
_repo_root = Path(__file__).parents[3] if "__file__" in dir() else Path(r"d:\KDH\새 폴더\EveryMotor")
if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))

print("sys.path에 추가:", _repo_root)
# Out:
# sys.path에 추가: d:\KDH\새 폴더\EveryMotor

# %%
from eMach.tools.motorCAD.pyMCAD.scaling import (
    def_scaling_factor, get_mcad_machine_data,
    get_mcad_building_data, sl_scale_machine, apply_scaled_data_to_mcad,
)

# %%
from eMach.tools.motorCAD.pyMCAD import def_scaling_factor, sl_scale_machine
